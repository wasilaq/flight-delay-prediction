# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Bad key "text.kerning_factor" on line 4 in
# /Users/wasilaq/opt/anaconda3/envs/metis/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.2/matplotlibrc.template
# or from the matplotlib source distribution

# %% [markdown]
# ### Finding Important Features

# %%
flights['tail_number'].nunique()
# Out:
# 2846

# %%
dayofwk_del = pd.crosstab(flights['dayofweek'],flights['arrdel15'].astype(bool))
dayofwk_del.div(dayofwk_del.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
deststate_del = pd.crosstab(flights['deststate'],flights['arrdel15'].astype(bool))
deststate_del.div(deststate_del.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, figsize=(15,5))

# %%
flights['deststate'].value_counts()
# Out:
# FL    4982
# TX    2215
# VA    1731
# NC    1673
# NY    1415
# CA    1235
# IL    1201
# TN    1178
# LA    1059
# PA     945
# AL     915
# SC     842
# OH     765
# MO     754
# GA     751
# MI     666
# IN     615
# KY     599
# CO     564
# MD     512
# MA     509
# NJ     481
# MN     418
# WI     412
# NV     375
# AR     357
# MS     349
# AZ     330
# OK     282
# UT     229
# WA     192
# CT     171
# NE     159
# IA     132
# WV     112
# PR     105
# OR      85
# KS      84
# RI      76
# VI      51
# NM      49
# NH      31
# HI      31
# VT      28
# ME      25
# SD      20
# WY      11
# MT       9
# ND       5
# Name: deststate, dtype: int64

# %%
op_airline_del = pd.crosstab(flights['operating_airline'],flights['arrdel15'].astype(bool))
op_airline_del.div(op_airline_del.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, figsize=(15,5))

# %%
flights['operating_airline'].value_counts()
# Out:
# DL    18573
# WN     3387
# OO     2043
# 9E     1689
# AA      920
# EV      860
# NK      619
# UA      420
# YX      386
# F9      268
# YV      171
# B6      137
# G7      109
# OH       65
# MQ       51
# AS       37
# Name: operating_airline, dtype: int64

# %%
flights.distance.value_counts()
# Out:
# 594.0     990
# 404.0     766
# 762.0     738
# 606.0     672
# 581.0     652
#          ...
# 1352.0     10
# 1640.0      9
# 1993.0      6
# 1123.0      5
# 717.0       1
# Name: distance, Length: 152, dtype: int64

# %%
dist_del = pd.crosstab(flights['distance'],flights['arrdel15'].astype(bool))
dist_del.div(dist_del.sum(1).astype(float), axis=0).plot(kind='line', figsize=(15,5))

# %% [markdown]
# ### Checking Class Imbalance

# %%
flights['arrdel15'].value_counts()
# Out:
# 0.0    24892
# 1.0     4843
# Name: arrdel15, dtype: int64

# %%
all_flights['Type'] = all_flights['Type'].fillna('None')
all_flights['severity'] = all_flights['severity'].fillna('None')

# %%
all_flights.Type.value_counts()
# Out:
# None    26207
# Rain     2881
# Fog       410
# Snow      237
# Name: Type, dtype: int64

# %% [markdown]
# ### Explore New DF

# %%
precipitation_del = pd.crosstab(all_flights['Type'],all_flights['arrdel15'].astype(bool))
precipitation_del.div(precipitation_del.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
sev_del = pd.crosstab(all_flights['severity'],all_flights['arrdel15'].astype(bool))
sev_del.div(sev_del.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)

# %%
# MVP

precipitation_del.div(precipitation_del.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title('Origin Airport Precipitation & Arrival Delays', fontsize=14)

sev_del.div(sev_del.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, legend=False)
plt.title('Origin Airport Weather Severity & Arrival Delays', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Origin Airport Weather Severity & Arrival Delays')

# %%
all_flights.Type.value_counts()
# Out:
# None    26207
# Rain     2881
# Fog       410
# Snow      237
# Name: Type, dtype: int64

# %%
all_flights.severity.value_counts()
# Out:
# None        26207
# Light        2802
# Severe        410
# Moderate      316
# Name: severity, dtype: int64

# %%
convert = ['dayofweek','depdel15','taxiout','taxiin','arrdel15','airtime','distance']

for column in convert:
    all_flights[column] = all_flights[column].apply(lambda x: int(x))
