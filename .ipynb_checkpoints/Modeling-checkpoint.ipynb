# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score
# from sklearn.metrics import confusion_matrix
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

from imblearn.over_sampling import RandomOverSampler

# %%
pd.set_option('display.max_rows', 500)

# %% [markdown]
# # Import and Cleaning

# %%
df = pd.read_csv('final.csv', index_col = 0)

# %%
df['target_delay'] = df['arr_delay'].apply(lambda x: 1 if x > 15 else 0)
df = df[df['dest_weather_severity'] != 'UNK']
df = df[df['origin_weather_severity'] != 'UNK']
df.drop(columns = ['canceled', 'num_of_flights'], inplace = True)

# %%
df.columns
# Out:
# Index(['day_of_week', 'flight_date', 'reporting_airline', 'name',
#        'tail_number', 'origin', 'origin_city', 'origin_statecode', 'dest',
#        'dest_city', 'dest_statecode', 'dep_delay', 'arr_delay', 'diverted',
#        'set_elapsed_time', 'actual_elapsed_time', 'miles', 'diverted_landings',
#        'origin_timezone', 'dest_timezone', 'arrtime', 'deptime', 'set_arrtime',
#        'set_deptime', 'dep', 'dep_utc', 'arr_utc', 'origin_weather_type',
#        'origin_weather_severity', 'dest_weather_type', 'dest_weather_severity',
#        'target_delay'],
#       dtype='object')

# %%
df.head()
# Out:
#   day_of_week flight_date reporting_airline              name tail_number  \
# 0      Monday  2019-04-01                NK  Spirit Air Lines      N605NK
# 1      Monday  2019-04-08                NK  Spirit Air Lines      N904NK
# 2      Monday  2019-04-15                NK  Spirit Air Lines      N637NK
# 3      Monday  2019-04-22                NK  Spirit Air Lines      N619NK
# 4      Monday  2019-04-29                NK  Spirit Air Lines      N644NK
#
#   origin    origin_city origin_statecode dest    dest_city  ... set_arrtime  \
# 0    BWI  Baltimore, MD               MD  MCO  Orlando, FL  ...    12:12:00
# 1    BWI  Baltimore, MD               MD  MCO  Orlando, FL  ...    12:12:00
# 2    BWI  Baltimore, MD               MD  MCO  Orlando, FL  ...    12:12:00
# 3    BWI  Baltimore, MD               MD  MCO  Orlando, FL  ...    12:12:00
# 4    BWI  Baltimore, MD               MD  MCO  Orlando, FL  ...    12:12:00
#
#    set_deptime                  dep              dep_utc              arr_utc  \
# 0     10:10:00  2019-04-01 10:10:00  2019-04-01 15:10:00  2019-04-01 17:35:00
# 1     10:10:00  2019-04-08 10:10:00  2019-04-08 15:10:00  2019-04-08 17:35:00
# 2     10:10:00  2019-04-15 10:10:00  2019-04-15 15:10:00  2019-04-15 17:35:00
# 3     10:10:00  2019-04-22 11:11:00  2019-04-22 16:11:00  2019-04-22 18:36:00
# 4     10:10:00  2019-04-29 10:10:00  2019-04-29 15:10:00  2019-04-29 17:35:00
#
#    origin_weather_type  origin_weather_severity  dest_weather_type  \
# 0                  NaN                      NaN                NaN
# 1                  NaN                      NaN                NaN
# 2                Storm                   Severe                NaN
# 3                  NaN                      NaN                NaN
# 4                  NaN                      NaN                NaN
#
#   dest_weather_severity target_delay
# 0                   NaN            1
# 1                   NaN            0
# 2                   NaN            0
# 3                   NaN            1
# 4                   NaN            0
#
# [5 rows x 32 columns]

# %% [markdown]
# # EDA

# %%
precipitation_del_d = pd.crosstab(df['dest_weather_type'], df['target_delay'].astype(bool))
precipitation_del_d.div(precipitation_del_d.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title("Destination Weather")

precipitation_del_o = pd.crosstab(df['origin_weather_type'], df['target_delay'].astype(bool))
precipitation_del_o.div(precipitation_del_o.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
plt.title("Origin Weather")
# Out:
# Text(0.5, 1.0, 'Origin Weather')

# %%
dayofwk_del = pd.crosstab(df['day_of_week'], df['target_delay'].astype(bool))
dayofwk_del.div(dayofwk_del.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True)
# Out:
# <AxesSubplot:xlabel='day_of_week'>

# %%
deststate_del = pd.crosstab(df['dest_statecode'],df['target_delay'].astype(bool))
deststate_del.div(deststate_del.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='dest_statecode'>

# %%
deststate_del = pd.crosstab(df['origin_statecode'], df['target_delay'].astype(bool))
deststate_del.div(deststate_del.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='origin_statecode'>

# %%
op_airline_del = pd.crosstab(df['reporting_airline'], df['target_delay'].astype(bool))
op_airline_del.div(op_airline_del.sum(1).astype(float), axis=0).plot(kind='bar', stacked=True, figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='reporting_airline'>

# %% [markdown]
# ## Correlations

# %%
categorical = [
    'day_of_week', 'reporting_airline', 'origin_statecode', 'dest_statecode', 'origin_weather_type', 'origin_weather_severity', 'dest_weather_type', 'dest_weather_severity'
]

data_types = dict()

for x in categorical:
    data_types[x] = 'category' 

data_types['miles'] = 'uint16'
data_types['target_delay'] = 'uint8'
    
data = df.drop(
    columns = [
        'arrtime', 'set_arrtime', 'dep_utc', 'arr_utc', 'flight_date', 'name', 'tail_number', 'dep_delay', 'diverted', 'arr_delay', 'actual_elapsed_time', 'set_elapsed_time', 'origin', 'origin_city', 'dest', 'dest_city', 'deptime', 'set_deptime', 'dep', 'origin_timezone', 'dest_timezone', 'diverted_landings'
    ]
).astype(data_types)

# %%
data.columns
# Out:
# Index(['day_of_week', 'reporting_airline', 'origin_statecode',
#        'dest_statecode', 'miles', 'origin_weather_type',
#        'origin_weather_severity', 'dest_weather_type', 'dest_weather_severity',
#        'target_delay'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2151070 entries, 0 to 2155433
# Data columns (total 10 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   day_of_week              category
#  1   reporting_airline        category
#  2   origin_statecode         category
#  3   dest_statecode           category
#  4   miles                    uint16
#  5   origin_weather_type      category
#  6   origin_weather_severity  category
#  7   dest_weather_type        category
#  8   dest_weather_severity    category
#  9   target_delay             uint8
# dtypes: category(8), uint16(1), uint8(1)
# memory usage: 39.0 MB

# %%
data2 = pd.get_dummies(data, drop_first = True)

# %%
# standardize miles so that its between 0 and 1 like all other features
minimum = min(data2['miles'])
maximum = max(data2['miles'])

data2['miles'] = data2['miles'].apply(lambda x: (x - minimum)/(maximum - minimum))

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2151070 entries, 0 to 2155433
# Data columns (total 95 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   miles                             uint16
#  1   target_delay                      uint8
#  2   day_of_week_Monday                uint8
#  3   day_of_week_Saturday              uint8
#  4   day_of_week_Sunday                uint8
#  5   day_of_week_Thursday              uint8
#  6   day_of_week_Tuesday               uint8
#  7   day_of_week_Wednesday             uint8
#  8   reporting_airline_AA              uint8
#  9   reporting_airline_AS              uint8
#  10  reporting_airline_B6              uint8
#  11  reporting_airline_DL              uint8
#  12  reporting_airline_EV              uint8
#  13  reporting_airline_F9              uint8
#  14  reporting_airline_G4              uint8
#  15  reporting_airline_MQ              uint8
#  16  reporting_airline_NK              uint8
#  17  reporting_airline_OH              uint8
#  18  reporting_airline_OO              uint8
#  19  reporting_airline_UA              uint8
#  20  reporting_airline_WN              uint8
#  21  reporting_airline_YV              uint8
#  22  reporting_airline_YX              uint8
#  23  origin_statecode_AR               uint8
#  24  origin_statecode_AZ               uint8
#  25  origin_statecode_CA               uint8
#  26  origin_statecode_CO               uint8
#  27  origin_statecode_CT               uint8
#  28  origin_statecode_FL               uint8
#  29  origin_statecode_GA               uint8
#  30  origin_statecode_IA               uint8
#  31  origin_statecode_ID               uint8
#  32  origin_statecode_IL               uint8
#  33  origin_statecode_IN               uint8
#  34  origin_statecode_KS               uint8
#  35  origin_statecode_KY               uint8
#  36  origin_statecode_LA               uint8
#  37  origin_statecode_MA               uint8
#  38  origin_statecode_MD               uint8
#  39  origin_statecode_ME               uint8
#  40  origin_statecode_MI               uint8
#  41  origin_statecode_MN               uint8
#  42  origin_statecode_MO               uint8
#  43  origin_statecode_MS               uint8
#  44  origin_statecode_MT               uint8
#  45  origin_statecode_NC               uint8
#  46  origin_statecode_ND               uint8
#  47  origin_statecode_NE               uint8
#  48  origin_statecode_NH               uint8
#  49  origin_statecode_NJ               uint8
#  50  origin_statecode_NM               uint8
#  51  origin_statecode_NV               uint8
#  52  origin_statecode_NY               uint8
#  53  origin_statecode_OH               uint8
#  54  origin_statecode_OK               uint8
#  55  origin_statecode_OR               uint8
#  56  origin_statecode_PA               uint8
#  57  origin_statecode_RI               uint8
#  58  origin_statecode_SC               uint8
#  59  origin_statecode_SD               uint8
#  60  origin_statecode_TN               uint8
#  61  origin_statecode_TX               uint8
#  62  origin_statecode_UT               uint8
#  63  origin_statecode_VA               uint8
#  64  origin_statecode_VT               uint8
#  65  origin_statecode_WA               uint8
#  66  origin_statecode_WI               uint8
#  67  origin_statecode_WV               uint8
#  68  origin_statecode_WY               uint8
#  69  dest_statecode_CO                 uint8
#  70  dest_statecode_FL                 uint8
#  71  dest_statecode_GA                 uint8
#  72  dest_statecode_IL                 uint8
#  73  dest_statecode_NV                 uint8
#  74  dest_statecode_NY                 uint8
#  75  dest_statecode_TX                 uint8
#  76  dest_statecode_WA                 uint8
#  77  origin_weather_type_Fog           uint8
#  78  origin_weather_type_Hail          uint8
#  79  origin_weather_type_Rain          uint8
#  80  origin_weather_type_Snow          uint8
#  81  origin_weather_type_Storm         uint8
#  82  origin_weather_severity_Light     uint8
#  83  origin_weather_severity_Moderate  uint8
#  84  origin_weather_severity_Other     uint8
#  85  origin_weather_severity_Severe    uint8
#  86  dest_weather_type_Fog             uint8
#  87  dest_weather_type_Hail            uint8
#  88  dest_weather_type_Rain            uint8
#  89  dest_weather_type_Snow            uint8
#  90  dest_weather_type_Storm           uint8
#  91  dest_weather_severity_Light       uint8
#  92  dest_weather_severity_Moderate    uint8
#  93  dest_weather_severity_Other       uint8
#  94  dest_weather_severity_Severe      uint8
# dtypes: uint16(1), uint8(94)
# memory usage: 213.3 MB

# %%
corr = data2.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# %%
corr['target_delay'].sort_values()
# Out:
# dest_statecode_GA                  -0.064448
# reporting_airline_DL               -0.062796
# day_of_week_Tuesday                -0.015319
# reporting_airline_WN               -0.014066
# day_of_week_Saturday               -0.012873
# origin_statecode_SC                -0.011815
# origin_statecode_VA                -0.010443
# origin_statecode_FL                -0.010156
# origin_statecode_OH                -0.008953
# origin_statecode_UT                -0.007631
# dest_statecode_NV                  -0.007340
# origin_statecode_OK                -0.006196
# origin_statecode_TN                -0.006153
# origin_statecode_AZ                -0.005841
# origin_statecode_OR                -0.005476
# origin_statecode_GA                -0.004825
# origin_statecode_NM                -0.004301
# origin_statecode_NE                -0.004035
# reporting_airline_YX               -0.004019
# origin_statecode_IN                -0.004008
# origin_statecode_LA                -0.003399
# origin_statecode_WI                -0.003277
# origin_statecode_MS                -0.003237
# origin_statecode_CT                -0.003222
# origin_statecode_CA                -0.003156
# origin_statecode_AR                -0.002502
# origin_statecode_ID                -0.002397
# origin_statecode_KY                -0.002145
# origin_statecode_RI                -0.001691
# day_of_week_Wednesday              -0.001650
# origin_statecode_MO                -0.001572
# origin_statecode_MN                -0.001566
# origin_statecode_MI                -0.001413
# origin_statecode_NH                -0.001204
# origin_statecode_MD                -0.001098
# reporting_airline_OH               -0.000714
# origin_statecode_KS                -0.000671
# origin_statecode_WA                -0.000512
# origin_statecode_NV                -0.000246
# origin_weather_type_Fog            -0.000182
# origin_statecode_NC                 0.000748
# reporting_airline_NK                0.001030
# dest_statecode_CO                   0.001099
# origin_statecode_MT                 0.001220
# dest_statecode_WA                   0.001815
# origin_statecode_PA                 0.001848
# origin_statecode_WV                 0.002129
# origin_statecode_ME                 0.002267
# origin_statecode_TX                 0.002724
# reporting_airline_G4                0.002734
# origin_statecode_VT                 0.002781
# dest_statecode_FL                   0.002953
# origin_statecode_IA                 0.003148
# dest_statecode_NY                   0.003240
# origin_statecode_WY                 0.003366
# dest_weather_severity_Other         0.003614
# dest_weather_type_Hail              0.003614
# day_of_week_Sunday                  0.004486
# origin_statecode_ND                 0.004687
# dest_weather_type_Fog               0.004690
# origin_statecode_SD                 0.004874
# dest_weather_type_Storm             0.006417
# reporting_airline_MQ                0.006662
# origin_weather_type_Storm           0.006785
# dest_statecode_TX                   0.007258
# origin_weather_severity_Severe      0.007298
# day_of_week_Monday                  0.007565
# reporting_airline_YV                0.007716
# origin_statecode_MA                 0.008951
# reporting_airline_UA                0.010027
# origin_weather_severity_Other       0.010269
# origin_weather_type_Hail            0.010269
# reporting_airline_AS                0.011735
# origin_statecode_NY                 0.012254
# reporting_airline_EV                0.013853
# dest_weather_severity_Severe        0.013980
# reporting_airline_OO                0.014638
# day_of_week_Thursday                0.015893
# origin_weather_severity_Moderate    0.019762
# origin_statecode_CO                 0.020003
# reporting_airline_B6                0.020862
# miles                               0.021505
# origin_statecode_IL                 0.022997
# dest_weather_severity_Moderate      0.023269
# origin_statecode_NJ                 0.024062
# reporting_airline_AA                0.024316
# dest_statecode_IL                   0.031786
# reporting_airline_F9                0.031790
# origin_weather_type_Rain            0.056694
# dest_weather_type_Snow              0.058882
# dest_weather_type_Rain              0.078108
# origin_weather_severity_Light       0.078406
# dest_weather_severity_Light         0.084098
# origin_weather_type_Snow            0.090317
# target_delay                        1.000000
# Name: target_delay, dtype: float64

# %%
sns.set_style(style = 'white')
f, ax = plt.subplots(figsize=(15, 12))
cmap = sns.diverging_palette(10, 250, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap, square=True, linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Data Setup

# %%
X = data2.drop(columns = ['target_delay'])
y = data2['target_delay']

X_tv, X_test, y_tv, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %% [markdown]
# ### Class Imbalance

# %%
data2['target_delay'].value_counts()
# Out:
# 0    1743790
# 1     407280
# Name: target_delay, dtype: int64

# %%
# setup for the ratio argument of RandomOverSampler initialization
n_pos = np.sum(y_tv == 1)
n_neg = np.sum(y_tv == 0)
ratio = {1 : n_pos * 3, 0 : n_neg} 

# randomly oversample positive samples: create 4x as many 
ROS = RandomOverSampler(sampling_strategy = ratio, random_state=42) 

X_tv_rs, y_tv_rs = ROS.fit_sample(X_tv, y_tv)

# %% [markdown]
# ## Models

# %% [markdown]
# Using F1 score
# * False positives and false negatives are equally important

# %% [markdown]
# ### Dummy Classifier

# %%
dc = DummyClassifier()

cross_val_score(dc, X_tv_rs, y_tv_rs, cv=5, scoring='f1')
# Out:
# array([0., 0., 0., 0., 0.])

# %% [markdown]
# ### Logistic Regression

# %% [markdown]
# #### Adjust Class Weights

# %%
lr = LogisticRegression(class_weight='balanced', max_iter=200)

# %%
cross_val_score(lr, X_tv, y_tv, cv=5, scoring='f1')
# Out:
# array([0.33504967, 0.33578621, 0.3350342 , 0.33569506, 0.33481073])

# %% [markdown]
# #### Oversampling

# %%
lr2 = LogisticRegression(max_iter=200)

# %%
cross_val_score(lr2, X_tv_rs, y_tv_rs, cv=5, scoring='f1')
# Out:
# array([0.30451751, 0.30289307, 0.30164885, 0.30343357, 0.3042331 ])

# %% [markdown]
# *TO DO:*
# * *plot F1 score against different probability thresholds*

# %% [markdown]
# Optimal method: **logistic regression with adjusted class weight**

# %% [markdown]
# ### KNN

# %% [markdown]
# * KNN is slow to train. Unable to find optimal k value

# %% [markdown]
# ### Random Forest

# %% [markdown]
# * Random forest is slow to train

# %% [markdown]
# #### Adjust class weights

# %%
rfc = RandomForestClassifier(class_weight='balanced')

# %%
cross_val_score(rfc, X_tv, y_tv, cv = 5, scoring='f1')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-30ac0842df60> in <module>
# ----> 1 cross_val_score(rfc, X_tv, y_tv, cv = 5, scoring='f1')
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     438     scorer = check_scoring(estimator, scoring=scoring)
#     439
# --> 440     cv_results = cross_validate(estimator=estimator, X=X, y=y, groups=groups,
#     441                                 scoring={'score': scorer}, cv=cv,
#     442                                 n_jobs=n_jobs, verbose=verbose,
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     244     parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     245                         pre_dispatch=pre_dispatch)
# --> 246     results = parallel(
#     247         delayed(_fit_and_score)(
#     248             clone(estimator), X, y, scorers, train, test, verbose, None,
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
#    1042                 self._iterating = self._original_iterator is not None
#    1043
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     591             estimator.fit(X_train, **fit_params)
#     592         else:
# --> 593             estimator.fit(X_train, y_train, **fit_params)
#     594
#     595     except Exception as e:
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     385             # parallel_backend contexts set at a higher level,
#     386             # since correctness does not rely on using threads.
# --> 387             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     388                              **_joblib_parallel_args(prefer='threads'))(
#     389                 delayed(_parallel_build_trees)(
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/sklearn/ensemble/_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     167                                                         indices=indices)
#     168
# --> 169         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     170     else:
#     171         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     896         """
#     897
# --> 898         super().fit(
#     899             X, y,
#     900             sample_weight=sample_weight,
#
# ~/opt/anaconda3/envs/fdp/lib/python3.8/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     387                                            min_impurity_split)
#     388
# --> 389         builder.build(self.tree_, X, y, sample_weight)
#     390
#     391         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %% [markdown]
# #### Oversampling

# %%
rfc2 = RandomForestClassifier()

# %%
cross_val_score(rfc2, X_tv_rs, y_tv_rs, cv = 5, scoring='f1')

# %% [markdown]
# *TO DO:*
# * *optimize number of trees and maximum depth*

# %% [markdown]
# #### Old Code (to delete/redo)

# %% [markdown]
# *Old Code: Review Number of Trees*

# %%
rfc_150 = RandomForestClassifier(n_estimators=150, class_weight='balanced').fit(X_train, y_train)
# Out:
# 0.6997051804015162

# %%
cross_val_score(rfc_150, X_val, y_val, cv=5, scoring='fl')
# Out:
# array([0.1650165 , 0.20261438, 0.20754717, 0.2042042 , 0.20261438])

# %%
rfc_75 = RandomForestClassifier(n_estimators=75, class_weight='balanced').fit(X_train, y_train)
# Out:
# 0.6976013706453454

# %%
cross_val_score(rfc_75, X_val, y_val, cv=5, scoring='f1')
# Out:
# array([0.17880795, 0.2278481 , 0.19745223, 0.23255814, 0.23566879])

# %%
rfc_50 = RandomForestClassifier(n_estimators=50, class_weight='balanced').fit(X_train, y_train)
# Out:
# 0.6921981776765377

# %%
cross_val_score(rfc_50, X_val, y_val, cv=5, scoring='f1')
# Out:
# array([0.15384615, 0.2       , 0.17647059, 0.21752266, 0.2020202 ])

# %% [markdown]
# *Old code: max depth (pruning)*

# %%
rfc_5 = RandomForestClassifier(n_estimators=75, max_depth=50, class_weight='balanced').fit(X_train_adj, y_train_adj)

# %%
cross_val_score(rfc_5, X_val, y_val, cv=5, scoring='f1')
# Out:
# 0.5943584623065402
# array([0.30625832, 0.31746032, 0.34680135, 0.31441048, 0.33385335])

# %%
rfc_6 = RandomForestClassifier(n_estimators=75, max_depth=30, class_weight='balanced').fit(X_train_adj, y_train_adj)

# %%
cross_val_score(rfc_6, X_val, y_val, cv=5, scoring='f1')
# Out:
# 0.5938893751823601
# array([0.30898876, 0.3045388 , 0.3360522 , 0.31683168, 0.33385335])

# %% [markdown]
# *TO DO: SVM & naive bayes?*

# %% [markdown]
# ## Model Comparison

# %%
cross_val_score(final_rfc, X_val, y_val, cv=5, scoring='roc_auc')

# %%
final_lr = LogisticRegression(class_weight='balanced', max_iter=200)

cross_val_score(final_lr, X_val, y_val, cv=5, scoring='roc_auc')

# %% [markdown]
# Best model:

# %% [markdown]
# ### Final Score

# %%
test_pred = best.predict(X_test)

# %%
f1_score(y_test, test_pred)

# %%
confusion_matrix(y_test, test_pred)

# %% [markdown]
# # Exporting Results

# %%
pred_prob = best.predict_proba(X_test)[:,1]

# %%
results = data2
results['prediction'] = test_pred
results['pred_prob_delay'] = pred_prob

# %%
results.to_csv('results.csv', index = False)
