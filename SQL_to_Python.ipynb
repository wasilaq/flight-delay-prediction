# %% [markdown]
# Notebook Objectives
# * Converting data to pandas dataframes
# * Pickling dataframes for quick access

# %%
from sqlalchemy import create_engine
import pandas as pd
import datetime

# %%
cnx = create_engine('postgresql://ubuntu@3.23.86.219:5432/flights')

# weather data for ATL airport
weather = pd.read_sql_query(
    '''
    SELECT * FROM airport_weather aw WHERE airportcode = 'KATL'
    ''', cnx
)

weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2285 entries, 0 to 2284
# Data columns (total 13 columns):
# eventid           2285 non-null object
# Type              2285 non-null object
# severity          2285 non-null object
# StartTime(UTC)    2285 non-null datetime64[ns]
# EndTime(UTC)      2285 non-null datetime64[ns]
# timezone          2285 non-null object
# airportcode       2285 non-null object
# locationlat       2285 non-null float64
# locationlng       2285 non-null float64
# city              2285 non-null object
# county            2285 non-null object
# state             2285 non-null object
# zipcode           2285 non-null object
# dtypes: datetime64[ns](2), float64(2), object(9)
# memory usage: 232.2+ KB

# %%
month_mask = weather['StartTime(UTC)'].map(lambda x: x.month) == 1
year_mask = weather['StartTime(UTC)'].map(lambda x: x.year) == 2018

weather_jan18 = weather[month_mask & year_mask]

# %%
weather_jan18.to_pickle('/Users/wasilaq/Metis/Proj3/pickled_files/weather_jan18')

# %%
# flight data for ATL airport
flights = pd.read_sql_query(
    '''
    SELECT * FROM flights_jan18 fj WHERE origin = 'ATL'
    ''', cnx
)

flights.head()
# Out:
#    dayofmonth  dayofweek  flightdate marketing_airline_network  \
# 0          29          1  2018-01-29                        UA
# 1          29          1  2018-01-29                        UA
# 2          29          1  2018-01-29                        UA
# 3          29          1  2018-01-29                        UA
# 4          29          1  2018-01-29                        UA
#
#   dot_id_marketing_airline flight_number_marketing_airline operating_airline  \
# 0                    19977                             421                UA
# 1                    19977                             356                UA
# 2                    19977                             313                UA
# 3                    19977                             311                UA
# 4                    19977                             258                UA
#
#   dot_id_operating_airline tail_number flight_number_operating_airline  ...  \
# ...

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29735 entries, 0 to 29734
# Data columns (total 42 columns):
# dayofmonth                         29735 non-null int64
# dayofweek                          29735 non-null int64
# flightdate                         29735 non-null object
# marketing_airline_network          29735 non-null object
# dot_id_marketing_airline           29735 non-null object
# flight_number_marketing_airline    29735 non-null object
# operating_airline                  29735 non-null object
# dot_id_operating_airline           29735 non-null object
# tail_number                        29735 non-null object
# flight_number_operating_airline    29735 non-null object
# originairportid                    29735 non-null object
# originairportseqid                 29735 non-null object
# origincitymarketid                 29735 non-null object
# origin                             29735 non-null object
# origincityname                     29735 non-null object
# ...

# %%
flights.to_pickle('/Users/wasilaq/Metis/Proj3/pickled_files/flights')
